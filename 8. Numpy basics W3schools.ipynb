# %% [markdown]
# Write a NumPy program to test whether none of the elements of a given array is zero

# %%
import numpy as np

# %%
given_array = np.random.randint(0,100,(5,6))
print(given_array)
# Out:
# [[49 67 41 48 13 45]
#  [96 73 86 40 23 98]
#  [12 95 87 89 11 85]
#  [62 77 47 37 33 74]
#  [70  0 68 33  5 71]]

# %%
np.all(given_array)
# Out:
# False

# %%
(given_array != 0).all()
# Out:
# False

# %% [markdown]
# Write a NumPy program to test whether any of the elements of a given array is non-zero.

# %%
given_array = np.random.randint(0,100, (6,4))

# %%
np.any(given_array)
# Out:
# True

# %% [markdown]
# Write a NumPy program to test a given array element-wise for finiteness (not infinity or not a Number).

# %%
given_array = np.random.randint(1,87,(6,7))

# %%
np.isfinite(given_array).all()
# Out:
# True

# %%
given_array = np.array([1 , 644, np.nan , np.inf])

# %%
np.isfinite(given_array).all()
# Out:
# False

# %% [markdown]
# Write a NumPy program to test a given array element-wise for finiteness (not infinity or not a Number).

# %%
given_array = np.array([1,5,np.inf , np.nan])

# %%
np.isfinite(given_array)
#isnan to check "not a number"
#isinf to check infinte values
#iscomplex , isreal , isscalar, isinf, isnan
# Out:
# array([ True,  True, False, False])

# %% [markdown]
# Write a NumPy program to test whether two arrays are element-wise equal within a tolerance.<br> #Solution pending
